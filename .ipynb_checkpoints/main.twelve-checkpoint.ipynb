# %%
from music21 import serial,note,stream,corpus,chord,environment,converter,midi

ttr = serial.TwelveToneRow([0, 2, 11, 7, 8, 3, 9, 1, 4, 10, 5, 6])
aMatrix = ttr.matrix()
print(aMatrix)
# Out:
#   0  2  B  7  8  3  9  1  4  A  5  6
#   A  0  9  5  6  1  7  B  2  8  3  4
#   1  3  0  8  9  4  A  2  5  B  6  7
#   5  7  4  0  1  8  2  6  9  3  A  B
#   4  6  3  B  0  7  1  5  8  2  9  A
#   9  B  8  4  5  0  6  A  1  7  2  3
#   3  5  2  A  B  6  0  4  7  1  8  9
#   B  1  A  6  7  2  8  0  3  9  4  5
#   8  A  7  3  4  B  5  9  0  6  1  2
#   2  4  1  9  A  5  B  3  6  0  7  8
#   7  9  6  2  3  A  4  8  B  5  0  1
#   6  8  5  1  2  9  3  7  A  4  B  0

# %%
ttr.show()

# %%
ttr.getIntervalsAsString()
# Out:
# '29817643671'

# %%
ttr.noteNames()
# Out:
# ['C', 'D', 'B', 'G', 'G#', 'E-', 'A', 'C#', 'E', 'B-', 'F', 'F#']

# %%
bStream = stream.Stream()
for i in range(0, 12, 3):
    c = chord.Chord(ttr[i:i + 3])
    c.addLyric(c.primeFormString)
    c.addLyric(c.forteClass)
    bStream.append(c)
bStream.show()

# %%
bStream.show('midi')
# Out:
#                 <div id='midiPlayerDiv3213'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv3213');
#                                mp.base64Load('...');
#                         });
#                 </script>

# %%
line = [5*i for i in range(12)]
r = serial.pcToToneRow(line)
r.noteNames()
# Out:
# ['C', 'F', 'B-', 'E-', 'G#', 'C#', 'F#', 'B', 'E', 'A', 'D', 'G']

# %%
r.isTwelveToneRow()
# Out:
# True

# %%
r.getIntervalsAsString()
# Out:
# '55555555555'

# %%
invalid_l = [6*i for i in range(12)]
invalid_r = serial.pcToToneRow(invalid_l)
invalid_r.noteNames()
# Out:
# ['C', 'F#', 'C', 'F#', 'C', 'F#', 'C', 'F#', 'C', 'F#', 'C', 'F#']

# %%
invalid_r.isTwelveToneRow()
# Out:
# False
